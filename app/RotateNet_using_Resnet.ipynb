# %% [markdown]
# ### Importing Libraries

# %%
import torch
from torchvision import models, datasets,transforms
from torch.utils.data import DataLoader
from torch import nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ### Transforming the images to tensor, and resize for Resnet model

# %%
train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                        [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %% [markdown]
# ### Loading the dataset

# %%
train_dir = './Data/Train'
test_dir = './Data/Test/'

# %%
bs = 16
train_data = datasets.ImageFolder(root = train_dir,transform=train_transform)
test_data = datasets.ImageFolder(root=test_dir, transform=test_transform)

print(len(train_data),len(test_data))


train_data_loader = DataLoader(train_data,batch_size=bs,shuffle=True)
test_data_loader = DataLoader(test_data,batch_size=bs, shuffle=False)
# Out:
# 10232 280

# %%
train_data_loader.dataset.classes
# Out:
# ['0', '180', '270', '90']

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ### Loading the pretrained model, changing the fast few layes

# %%
resnet50 = models.resnet50(pretrained=True)

# %%
for param in resnet50.parameters():
    param.require_grad = True

# %%
resnet50.fc = nn.Sequential(
    nn.Linear(2048,256),
    nn.ReLU(),
    nn.Dropout(0.6),
    nn.Linear(256, 4),
    nn.LogSoftmax(dim=1)    

)

# %%
device = 'cuda'
model = resnet50

# %%
model = model.to(device)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_2.parameters())

# %% [markdown]
# ### Model training

# %%
epochs = 30
training_loss = []
testing_loss = []
accuracy_list = []
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1,epochs))
    model.train()
    
    train_loss = 0.0
    test_loss = 0.0
    test_acc = 0.0
    

    
    for i , (inputs,labels) in enumerate(train_data_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        output = model(inputs)
        loss = loss_func(output,labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()*inputs.size(0)
#         writer.add_scalar('loss', loss, epoch)
        print("Batch number: {:03d}, Training_Loss: {:.4f},".format(i, loss.item()))


    with torch.no_grad():
        model.eval()
        num_correct = 0
        num_examples = 0
        

        for j , (inputs, target) in enumerate(test_data_loader):
            inputs = inputs.to(device)
            target = target.to(device)

            output = model(inputs)
            loss = loss_func(output, target)
            correct = torch.eq(torch.max(torch.functional.F.softmax(output), dim=1)[1], target).view(-1)
            num_correct += torch.sum(correct).item()
            num_examples += correct.shape[0]
            test_loss += loss.item()*inputs.size(0)
            print("Test Batch number: {:03d}, Test_Loss: {:.4f}, Accuracy:{:.2f}".format(j, loss.item(),num_correct/num_examples))
#             writer.add_scalar('accuracy', num_correct / num_examples, epoch)
#             writer.add_scalar('Test_loss', loss, epoch)
#             test_acc += num_correct

        
        
        
        
    avg_train_loss = train_loss/len(train_data)
    avg_test_loss = test_loss/len(test_data)
    avg_acc = num_correct/len(test_data)
    training_loss.append(avg_train_loss)
    testing_loss.append(avg_test_loss)
    accuracy_list.append(avg_acc)
# Out:
# Epoch: 1/30
# Batch number: 000, Training_Loss: 1.4054,
# Batch number: 001, Training_Loss: 1.4666,
# Batch number: 002, Training_Loss: 1.2632,
# Batch number: 003, Training_Loss: 1.5541,
# Batch number: 004, Training_Loss: 1.3297,
# Batch number: 005, Training_Loss: 1.2863,
# Batch number: 006, Training_Loss: 0.9773,
# Batch number: 007, Training_Loss: 1.2967,
# Batch number: 008, Training_Loss: 1.5524,
# Batch number: 009, Training_Loss: 1.1214,
# Batch number: 010, Training_Loss: 1.7607,
# Batch number: 011, Training_Loss: 1.2215,
# Batch number: 012, Training_Loss: 0.7661,
# Batch number: 013, Training_Loss: 0.9605,
# Batch number: 014, Training_Loss: 1.3901,
# Batch number: 015, Training_Loss: 0.8867,
# Batch number: 016, Training_Loss: 1.2671,
# Batch number: 017, Training_Loss: 1.4254,
# Batch number: 018, Training_Loss: 0.8163,
# Batch number: 019, Training_Loss: 0.9535,
# Batch number: 020, Training_Loss: 1.2793,
# Batch number: 021, Training_Loss: 0.9191,
# Batch number: 022, Training_Loss: 1.7339,
# Batch number: 023, Training_Loss: 1.3941,
# Batch number: 024, Training_Loss: 0.9121,
# Batch number: 025, Training_Loss: 1.0863,
# Batch number: 026, Training_Loss: 0.9435,
# Batch number: 027, Training_Loss: 1.1655,
# Batch number: 028, Training_Loss: 1.1241,
# Batch number: 029, Training_Loss: 1.0748,
# Batch number: 030, Training_Loss: 1.0253,
# Batch number: 031, Training_Loss: 0.9329,
# Batch number: 032, Training_Loss: 1.4875,
# Batch number: 033, Training_Loss: 0.7782,
# Batch number: 034, Training_Loss: 0.7215,
# Batch number: 035, Training_Loss: 1.4026,
# Batch number: 036, Training_Loss: 1.2524,
# Batch number: 037, Training_Loss: 1.3148,
# Batch number: 038, Training_Loss: 0.8960,
# Batch number: 039, Training_Loss: 1.2246,
# Batch number: 040, Training_Loss: 1.0910,
# Batch number: 041, Training_Loss: 0.8694,
# Batch number: 042, Training_Loss: 1.1390,
# Batch number: 043, Training_Loss: 1.3616,
# Batch number: 044, Training_Loss: 1.0704,
# Batch number: 045, Training_Loss: 0.9686,
# Batch number: 046, Training_Loss: 1.0748,
# Batch number: 047, Training_Loss: 0.9325,
# Batch number: 048, Training_Loss: 1.0557,
# Batch number: 049, Training_Loss: 1.3531,
# Batch number: 050, Training_Loss: 0.9818,
# Batch number: 051, Training_Loss: 1.0304,
# Batch number: 052, Training_Loss: 1.0744,
# Batch number: 053, Training_Loss: 0.9082,
# Batch number: 054, Training_Loss: 0.8259,
# Batch number: 055, Training_Loss: 0.7756,
# Batch number: 056, Training_Loss: 0.8610,
# Batch number: 057, Training_Loss: 0.8843,
# Batch number: 058, Training_Loss: 0.8367,
# Batch number: 059, Training_Loss: 1.0603,
# Batch number: 060, Training_Loss: 1.0501,
# Batch number: 061, Training_Loss: 0.6876,
# Batch number: 062, Training_Loss: 1.1514,
# Batch number: 063, Training_Loss: 1.0397,
# Batch number: 064, Training_Loss: 1.0683,
# Batch number: 065, Training_Loss: 1.0776,
# Batch number: 066, Training_Loss: 1.0891,
# Batch number: 067, Training_Loss: 1.2177,
# Batch number: 068, Training_Loss: 1.3896,
# Batch number: 069, Training_Loss: 1.0959,
# Batch number: 070, Training_Loss: 1.0559,
# Batch number: 071, Training_Loss: 1.5064,
# Batch number: 072, Training_Loss: 1.3500,
# Batch number: 073, Training_Loss: 0.8051,
# Batch number: 074, Training_Loss: 0.8112,
# Batch number: 075, Training_Loss: 0.9301,
# Batch number: 076, Training_Loss: 0.9300,
# Batch number: 077, Training_Loss: 1.0243,
# Batch number: 078, Training_Loss: 0.9924,
# Batch number: 079, Training_Loss: 0.7126,
# Batch number: 080, Training_Loss: 1.1931,
# Batch number: 081, Training_Loss: 1.4229,
# Batch number: 082, Training_Loss: 0.9215,
# Batch number: 083, Training_Loss: 0.9555,
# Batch number: 084, Training_Loss: 1.2988,
# Batch number: 085, Training_Loss: 0.9610,
# Batch number: 086, Training_Loss: 0.8598,
# Batch number: 087, Training_Loss: 0.7424,
# Batch number: 088, Training_Loss: 0.7417,
# Batch number: 089, Training_Loss: 1.1706,
# Batch number: 090, Training_Loss: 0.7410,
# Batch number: 091, Training_Loss: 1.0846,
# Batch number: 092, Training_Loss: 0.8673,
# Batch number: 093, Training_Loss: 0.9922,
# Batch number: 094, Training_Loss: 0.7830,
# Batch number: 095, Training_Loss: 0.8522,
# Batch number: 096, Training_Loss: 0.7831,
# Batch number: 097, Training_Loss: 1.0410,
# Batch number: 098, Training_Loss: 0.9532,
# Batch number: 099, Training_Loss: 0.8515,
# Batch number: 100, Training_Loss: 0.8638,
# Batch number: 101, Training_Loss: 0.6314,
# Batch number: 102, Training_Loss: 0.9972,
# Batch number: 103, Training_Loss: 0.9457,
# Batch number: 104, Training_Loss: 0.6857,
# Batch number: 105, Training_Loss: 0.6966,
# Batch number: 106, Training_Loss: 1.7078,
# Batch number: 107, Training_Loss: 0.8080,
# Batch number: 108, Training_Loss: 0.9304,
# Batch number: 109, Training_Loss: 1.1896,
# Batch number: 110, Training_Loss: 0.6514,
# Batch number: 111, Training_Loss: 0.8058,
# Batch number: 112, Training_Loss: 0.9645,
# Batch number: 113, Training_Loss: 0.9782,
# Batch number: 114, Training_Loss: 0.8481,
# Batch number: 115, Training_Loss: 0.8680,
# Batch number: 116, Training_Loss: 0.9660,
# Batch number: 117, Training_Loss: 1.0062,
# Batch number: 118, Training_Loss: 1.0155,
# Batch number: 119, Training_Loss: 1.0144,
# Batch number: 120, Training_Loss: 1.0026,
# Batch number: 121, Training_Loss: 0.7487,
# Batch number: 122, Training_Loss: 0.8197,
# Batch number: 123, Training_Loss: 1.0329,
# Batch number: 124, Training_Loss: 0.8728,
# Batch number: 125, Training_Loss: 0.6950,
# Batch number: 126, Training_Loss: 0.9363,
# Batch number: 127, Training_Loss: 1.8447,
# Batch number: 128, Training_Loss: 0.7982,
# Batch number: 129, Training_Loss: 1.0960,
# Batch number: 130, Training_Loss: 0.6496,
# Batch number: 131, Training_Loss: 0.8779,
# Batch number: 132, Training_Loss: 1.0239,
# Batch number: 133, Training_Loss: 1.0195,
# Batch number: 134, Training_Loss: 0.6798,
# Batch number: 135, Training_Loss: 0.9604,
# Batch number: 136, Training_Loss: 0.7275,
# Batch number: 137, Training_Loss: 1.0549,
# Batch number: 138, Training_Loss: 1.2285,
# Batch number: 139, Training_Loss: 1.2522,
# Batch number: 140, Training_Loss: 0.7173,
# Batch number: 141, Training_Loss: 0.8240,
# Batch number: 142, Training_Loss: 0.8076,
# Batch number: 143, Training_Loss: 1.0224,
# Batch number: 144, Training_Loss: 0.8342,
# Batch number: 145, Training_Loss: 0.9823,
# Batch number: 146, Training_Loss: 0.8560,
# Batch number: 147, Training_Loss: 0.7656,
# Batch number: 148, Training_Loss: 0.6754,
# Batch number: 149, Training_Loss: 0.7930,
# Batch number: 150, Training_Loss: 0.8272,
# Batch number: 151, Training_Loss: 0.7753,
# Batch number: 152, Training_Loss: 1.0163,
# Batch number: 153, Training_Loss: 0.8679,
# Batch number: 154, Training_Loss: 0.7382,
# Batch number: 155, Training_Loss: 1.0999,
# Batch number: 156, Training_Loss: 1.1978,
# Batch number: 157, Training_Loss: 1.2517,
# Batch number: 158, Training_Loss: 0.8859,
# Batch number: 159, Training_Loss: 0.8488,
# Batch number: 160, Training_Loss: 0.6975,
# Batch number: 161, Training_Loss: 0.8045,
# Batch number: 162, Training_Loss: 0.7730,
# Batch number: 163, Training_Loss: 0.7627,
# Batch number: 164, Training_Loss: 1.4393,
# Batch number: 165, Training_Loss: 1.0147,
# Batch number: 166, Training_Loss: 1.3691,
# Batch number: 167, Training_Loss: 0.9657,
# Batch number: 168, Training_Loss: 0.9947,
# Batch number: 169, Training_Loss: 0.7006,
# Batch number: 170, Training_Loss: 0.8879,
# Batch number: 171, Training_Loss: 0.7135,
# Batch number: 172, Training_Loss: 0.8306,
# Batch number: 173, Training_Loss: 1.0180,
# Batch number: 174, Training_Loss: 0.8036,
# Batch number: 175, Training_Loss: 0.8804,
# Batch number: 176, Training_Loss: 0.7668,
# Batch number: 177, Training_Loss: 0.8927,
# Batch number: 178, Training_Loss: 0.7917,
# Batch number: 179, Training_Loss: 0.8085,
# Batch number: 180, Training_Loss: 0.9132,
# Batch number: 181, Training_Loss: 0.7662,
# Batch number: 182, Training_Loss: 0.8024,
# Batch number: 183, Training_Loss: 0.8239,
# Batch number: 184, Training_Loss: 0.8653,
# Batch number: 185, Training_Loss: 0.7596,
# Batch number: 186, Training_Loss: 1.1854,
# Batch number: 187, Training_Loss: 1.2869,
# Batch number: 188, Training_Loss: 1.0233,
# Batch number: 189, Training_Loss: 0.9413,
# Batch number: 190, Training_Loss: 0.7331,
# Batch number: 191, Training_Loss: 0.9549,
# Batch number: 192, Training_Loss: 0.7746,
# Batch number: 193, Training_Loss: 0.9445,
# Batch number: 194, Training_Loss: 0.8814,
# Batch number: 195, Training_Loss: 1.4079,
# Batch number: 196, Training_Loss: 0.9797,
# Batch number: 197, Training_Loss: 0.8109,
# Batch number: 198, Training_Loss: 0.7111,
# Batch number: 199, Training_Loss: 0.9141,
# Batch number: 200, Training_Loss: 0.7423,
# Batch number: 201, Training_Loss: 0.7242,
# Batch number: 202, Training_Loss: 0.8001,
# Batch number: 203, Training_Loss: 0.9339,
# Batch number: 204, Training_Loss: 0.9207,
# Batch number: 205, Training_Loss: 0.6982,
# Batch number: 206, Training_Loss: 0.6575,
# Batch number: 207, Training_Loss: 0.7968,
# Batch number: 208, Training_Loss: 0.7951,
# Batch number: 209, Training_Loss: 0.7860,
# Batch number: 210, Training_Loss: 0.9459,
# Batch number: 211, Training_Loss: 0.6847,
# Batch number: 212, Training_Loss: 0.8732,
# Batch number: 213, Training_Loss: 0.5877,
# Batch number: 214, Training_Loss: 0.9181,
# Batch number: 215, Training_Loss: 0.9871,
# Batch number: 216, Training_Loss: 0.7753,
# Batch number: 217, Training_Loss: 0.8223,
# Batch number: 218, Training_Loss: 0.5731,
# Batch number: 219, Training_Loss: 0.8365,
# Batch number: 220, Training_Loss: 0.9075,
# Batch number: 221, Training_Loss: 0.7001,
# Batch number: 222, Training_Loss: 0.6550,
# Batch number: 223, Training_Loss: 0.7542,
# Batch number: 224, Training_Loss: 0.8795,
# Batch number: 225, Training_Loss: 0.7001,
# Batch number: 226, Training_Loss: 0.6836,
# Batch number: 227, Training_Loss: 0.7605,
# Batch number: 228, Training_Loss: 1.2770,
# Batch number: 229, Training_Loss: 0.7569,
# Batch number: 230, Training_Loss: 0.6415,
# Batch number: 231, Training_Loss: 1.1662,
# Batch number: 232, Training_Loss: 0.6771,
# Batch number: 233, Training_Loss: 0.9212,
# Batch number: 234, Training_Loss: 0.5078,
# Batch number: 235, Training_Loss: 0.5673,
# Batch number: 236, Training_Loss: 0.9441,
# Batch number: 237, Training_Loss: 1.3680,
# Batch number: 238, Training_Loss: 0.6670,
# Batch number: 239, Training_Loss: 1.3637,
# Batch number: 240, Training_Loss: 0.9670,
# Batch number: 241, Training_Loss: 0.8977,
# Batch number: 242, Training_Loss: 0.5984,
# Batch number: 243, Training_Loss: 0.6874,
# Batch number: 244, Training_Loss: 0.6744,
# Batch number: 245, Training_Loss: 0.8314,
# Batch number: 246, Training_Loss: 0.7422,
# Batch number: 247, Training_Loss: 0.8803,
# Batch number: 248, Training_Loss: 0.7445,
# Batch number: 249, Training_Loss: 1.0574,
# Batch number: 250, Training_Loss: 0.8594,
# Batch number: 251, Training_Loss: 0.7233,
# Batch number: 252, Training_Loss: 0.6933,
# Batch number: 253, Training_Loss: 0.6701,
# Batch number: 254, Training_Loss: 1.0386,
# Batch number: 255, Training_Loss: 0.6431,
# Batch number: 256, Training_Loss: 0.6905,
# Batch number: 257, Training_Loss: 0.7534,
# Batch number: 258, Training_Loss: 0.6654,
# Batch number: 259, Training_Loss: 0.9978,
# Batch number: 260, Training_Loss: 1.1220,
# Batch number: 261, Training_Loss: 0.9191,
# Batch number: 262, Training_Loss: 1.0370,
# Batch number: 263, Training_Loss: 0.5790,
# Batch number: 264, Training_Loss: 0.6593,
# Batch number: 265, Training_Loss: 0.6744,
# Batch number: 266, Training_Loss: 0.5257,
# Batch number: 267, Training_Loss: 0.6540,
# Batch number: 268, Training_Loss: 0.5471,
# Batch number: 269, Training_Loss: 0.6241,
# Batch number: 270, Training_Loss: 0.7157,
# Batch number: 271, Training_Loss: 0.8957,
# Batch number: 272, Training_Loss: 0.6021,
# Batch number: 273, Training_Loss: 0.6823,
# Batch number: 274, Training_Loss: 1.1185,
# Batch number: 275, Training_Loss: 0.5240,
# Batch number: 276, Training_Loss: 0.7606,
# Batch number: 277, Training_Loss: 0.8277,
# Batch number: 278, Training_Loss: 0.9085,
# Batch number: 279, Training_Loss: 1.1830,
# Batch number: 280, Training_Loss: 0.7009,
# Batch number: 281, Training_Loss: 0.5958,
# Batch number: 282, Training_Loss: 0.8471,
# Batch number: 283, Training_Loss: 1.0284,
# Batch number: 284, Training_Loss: 1.5327,
# Batch number: 285, Training_Loss: 0.6722,
# Batch number: 286, Training_Loss: 1.1488,
# Batch number: 287, Training_Loss: 0.5830,
# Batch number: 288, Training_Loss: 0.5579,
# Batch number: 289, Training_Loss: 0.6212,
# Batch number: 290, Training_Loss: 0.9336,
# Batch number: 291, Training_Loss: 0.6143,
# Batch number: 292, Training_Loss: 0.6842,
# Batch number: 293, Training_Loss: 0.9427,
# Batch number: 294, Training_Loss: 0.9253,
# Batch number: 295, Training_Loss: 0.8396,
# Batch number: 296, Training_Loss: 0.5694,
# Batch number: 297, Training_Loss: 0.6788,
# Batch number: 298, Training_Loss: 0.8002,
# Batch number: 299, Training_Loss: 0.8079,
# Batch number: 300, Training_Loss: 1.0555,
# Batch number: 301, Training_Loss: 0.9274,
# Batch number: 302, Training_Loss: 0.5647,
# Batch number: 303, Training_Loss: 1.4191,
# Batch number: 304, Training_Loss: 0.8550,
# Batch number: 305, Training_Loss: 0.6421,
# Batch number: 306, Training_Loss: 0.5975,
# Batch number: 307, Training_Loss: 0.6298,
# Batch number: 308, Training_Loss: 0.7884,
# Batch number: 309, Training_Loss: 0.8229,
# Batch number: 310, Training_Loss: 0.6534,
# Batch number: 311, Training_Loss: 0.7475,
# Batch number: 312, Training_Loss: 0.9294,
# Batch number: 313, Training_Loss: 0.9408,
# Batch number: 314, Training_Loss: 0.6757,
# Batch number: 315, Training_Loss: 0.6475,
# Batch number: 316, Training_Loss: 0.8661,
# Batch number: 317, Training_Loss: 0.5523,
# Batch number: 318, Training_Loss: 0.8020,
# Batch number: 319, Training_Loss: 0.6956,
# Batch number: 320, Training_Loss: 0.7015,
# Batch number: 321, Training_Loss: 0.7088,
# Batch number: 322, Training_Loss: 0.9342,
# Batch number: 323, Training_Loss: 0.6966,
# Batch number: 324, Training_Loss: 0.5739,
# Batch number: 325, Training_Loss: 0.6773,
# Batch number: 326, Training_Loss: 0.7486,
# Batch number: 327, Training_Loss: 0.8678,
# Batch number: 328, Training_Loss: 0.6950,
# Batch number: 329, Training_Loss: 0.6328,
# Batch number: 330, Training_Loss: 0.6245,
# Batch number: 331, Training_Loss: 0.6348,
# Batch number: 332, Training_Loss: 0.9773,
# Batch number: 333, Training_Loss: 0.7948,
# Batch number: 334, Training_Loss: 0.5514,
# Batch number: 335, Training_Loss: 0.8970,
# Batch number: 336, Training_Loss: 0.7043,
# Batch number: 337, Training_Loss: 0.6131,
# Batch number: 338, Training_Loss: 0.5779,
# Batch number: 339, Training_Loss: 0.7643,
# Batch number: 340, Training_Loss: 0.6198,
# Batch number: 341, Training_Loss: 0.5125,
# Batch number: 342, Training_Loss: 0.6018,
# Batch number: 343, Training_Loss: 1.2825,
# Batch number: 344, Training_Loss: 0.5792,
# Batch number: 345, Training_Loss: 0.6464,
# Batch number: 346, Training_Loss: 0.6446,
# Batch number: 347, Training_Loss: 1.5650,
# Batch number: 348, Training_Loss: 0.6152,
# Batch number: 349, Training_Loss: 0.7831,
# Batch number: 350, Training_Loss: 0.8572,
# Batch number: 351, Training_Loss: 0.8209,
# Batch number: 352, Training_Loss: 0.8265,
# Batch number: 353, Training_Loss: 0.6081,
# Batch number: 354, Training_Loss: 0.5714,
# Batch number: 355, Training_Loss: 0.8008,
# Batch number: 356, Training_Loss: 0.8564,
# Batch number: 357, Training_Loss: 1.1044,
# Batch number: 358, Training_Loss: 0.5040,
# Batch number: 359, Training_Loss: 0.8260,
# Batch number: 360, Training_Loss: 0.9543,
# Batch number: 361, Training_Loss: 0.9962,
# Batch number: 362, Training_Loss: 0.5959,
# Batch number: 363, Training_Loss: 0.9010,
# Batch number: 364, Training_Loss: 0.6657,
# Batch number: 365, Training_Loss: 0.7552,
# Batch number: 366, Training_Loss: 0.8202,
# Batch number: 367, Training_Loss: 0.6238,
# Batch number: 368, Training_Loss: 0.5598,
# Batch number: 369, Training_Loss: 0.6419,
# Batch number: 370, Training_Loss: 0.6321,
# Batch number: 371, Training_Loss: 0.7494,
# Batch number: 372, Training_Loss: 0.4790,
# Batch number: 373, Training_Loss: 1.0239,
# Batch number: 374, Training_Loss: 0.5613,
# Batch number: 375, Training_Loss: 0.5407,
# Batch number: 376, Training_Loss: 0.5745,
# Batch number: 377, Training_Loss: 0.6622,
# Batch number: 378, Training_Loss: 0.6334,
# Batch number: 379, Training_Loss: 0.9555,
# Batch number: 380, Training_Loss: 1.1664,
# Batch number: 381, Training_Loss: 0.7501,
# Batch number: 382, Training_Loss: 0.6319,
# Batch number: 383, Training_Loss: 0.8763,
# Batch number: 384, Training_Loss: 0.6390,
# Batch number: 385, Training_Loss: 0.9422,
# Batch number: 386, Training_Loss: 0.6843,
# Batch number: 387, Training_Loss: 0.6982,
# Batch number: 388, Training_Loss: 0.5902,
# Batch number: 389, Training_Loss: 0.9420,
# Batch number: 390, Training_Loss: 0.7196,
# Batch number: 391, Training_Loss: 0.8747,
# Batch number: 392, Training_Loss: 0.8064,
# Batch number: 393, Training_Loss: 0.7410,
# Batch number: 394, Training_Loss: 0.7974,
# Batch number: 395, Training_Loss: 0.5967,
# Batch number: 396, Training_Loss: 0.9380,
# Batch number: 397, Training_Loss: 0.8258,
# Batch number: 398, Training_Loss: 0.6956,
# Batch number: 399, Training_Loss: 0.6168,
# Batch number: 400, Training_Loss: 0.6886,
# Batch number: 401, Training_Loss: 1.1896,
# Batch number: 402, Training_Loss: 0.6290,
# Batch number: 403, Training_Loss: 0.6223,
# Batch number: 404, Training_Loss: 0.9315,
# Batch number: 405, Training_Loss: 0.6189,
# Batch number: 406, Training_Loss: 0.6365,
# Batch number: 407, Training_Loss: 0.5857,
# Batch number: 408, Training_Loss: 0.5976,
# Batch number: 409, Training_Loss: 0.5657,
# Batch number: 410, Training_Loss: 0.6224,
# Batch number: 411, Training_Loss: 0.6251,
# Batch number: 412, Training_Loss: 0.8071,
# Batch number: 413, Training_Loss: 0.8435,
# Batch number: 414, Training_Loss: 0.4887,
# Batch number: 415, Training_Loss: 0.6743,
# Batch number: 416, Training_Loss: 0.4659,
# Batch number: 417, Training_Loss: 0.7919,
# Batch number: 418, Training_Loss: 0.9786,
# Batch number: 419, Training_Loss: 0.9396,
# Batch number: 420, Training_Loss: 0.6940,
# Batch number: 421, Training_Loss: 0.8172,
# Batch number: 422, Training_Loss: 0.5710,
# Batch number: 423, Training_Loss: 0.5961,
# Batch number: 424, Training_Loss: 0.8093,
# Batch number: 425, Training_Loss: 1.1797,
# Batch number: 426, Training_Loss: 0.5737,
# Batch number: 427, Training_Loss: 0.6159,
# Batch number: 428, Training_Loss: 0.8015,
# Batch number: 429, Training_Loss: 0.4284,
# Batch number: 430, Training_Loss: 1.9113,
# Batch number: 431, Training_Loss: 0.9032,
# Batch number: 432, Training_Loss: 1.3489,
# Batch number: 433, Training_Loss: 0.5930,
# Batch number: 434, Training_Loss: 0.8486,
# Batch number: 435, Training_Loss: 0.6621,
# Batch number: 436, Training_Loss: 0.7230,
# Batch number: 437, Training_Loss: 0.6651,
# Batch number: 438, Training_Loss: 1.1759,
# Batch number: 439, Training_Loss: 0.8297,
# Batch number: 440, Training_Loss: 1.0521,
# Batch number: 441, Training_Loss: 1.1298,
# Batch number: 442, Training_Loss: 0.8065,
# Batch number: 443, Training_Loss: 0.5496,
# Batch number: 444, Training_Loss: 1.0437,
# Batch number: 445, Training_Loss: 0.7369,
# Batch number: 446, Training_Loss: 0.7237,
# Batch number: 447, Training_Loss: 0.8780,
# Batch number: 448, Training_Loss: 0.7256,
# Batch number: 449, Training_Loss: 0.7908,
# Batch number: 450, Training_Loss: 0.7277,
# Batch number: 451, Training_Loss: 0.9167,
# Batch number: 452, Training_Loss: 0.8657,
# Batch number: 453, Training_Loss: 0.7562,
# Batch number: 454, Training_Loss: 0.8691,
# Batch number: 455, Training_Loss: 0.8076,
# Batch number: 456, Training_Loss: 0.8044,
# Batch number: 457, Training_Loss: 0.7472,
# Batch number: 458, Training_Loss: 0.9526,
# Batch number: 459, Training_Loss: 0.8390,
# Batch number: 460, Training_Loss: 0.8083,
# Batch number: 461, Training_Loss: 0.6645,
# Batch number: 462, Training_Loss: 0.6224,
# Batch number: 463, Training_Loss: 0.7313,
# Batch number: 464, Training_Loss: 0.6048,
# Batch number: 465, Training_Loss: 0.7075,
# Batch number: 466, Training_Loss: 0.7085,
# Batch number: 467, Training_Loss: 0.6722,
# Batch number: 468, Training_Loss: 0.7221,
# Batch number: 469, Training_Loss: 0.6153,
# Batch number: 470, Training_Loss: 0.8906,
# Batch number: 471, Training_Loss: 0.7514,
# Batch number: 472, Training_Loss: 0.6107,
# Batch number: 473, Training_Loss: 0.9682,
# Batch number: 474, Training_Loss: 0.6040,
# Batch number: 475, Training_Loss: 0.7003,
# Batch number: 476, Training_Loss: 0.6345,
# Batch number: 477, Training_Loss: 0.6918,
# Batch number: 478, Training_Loss: 0.5472,
# Batch number: 479, Training_Loss: 0.7682,
# Batch number: 480, Training_Loss: 0.8287,
# Batch number: 481, Training_Loss: 0.9732,
# Batch number: 482, Training_Loss: 0.7735,
# Batch number: 483, Training_Loss: 0.6693,
# Batch number: 484, Training_Loss: 0.5551,
# Batch number: 485, Training_Loss: 0.6915,
# Batch number: 486, Training_Loss: 0.6732,
# Batch number: 487, Training_Loss: 0.6046,
# Batch number: 488, Training_Loss: 0.6420,
# Batch number: 489, Training_Loss: 0.7438,
# Batch number: 490, Training_Loss: 0.5154,
# Batch number: 491, Training_Loss: 0.5772,
# Batch number: 492, Training_Loss: 0.4986,
# Batch number: 493, Training_Loss: 0.7192,
# Batch number: 494, Training_Loss: 0.6040,
# Batch number: 495, Training_Loss: 0.4245,
# Batch number: 496, Training_Loss: 0.3578,
# Batch number: 497, Training_Loss: 0.4789,
# Batch number: 498, Training_Loss: 0.6417,
# Batch number: 499, Training_Loss: 0.6599,
# Batch number: 500, Training_Loss: 1.1977,
# Batch number: 501, Training_Loss: 0.5294,
# Batch number: 502, Training_Loss: 0.6170,
# Batch number: 503, Training_Loss: 0.8159,
# Batch number: 504, Training_Loss: 0.7804,
# Batch number: 505, Training_Loss: 1.2953,
# Batch number: 506, Training_Loss: 0.9367,
# Batch number: 507, Training_Loss: 0.9435,
# Batch number: 508, Training_Loss: 0.6914,
# Batch number: 509, Training_Loss: 0.7668,
# Batch number: 510, Training_Loss: 0.6023,
# Batch number: 511, Training_Loss: 0.6178,
# Batch number: 512, Training_Loss: 0.6331,
# Batch number: 513, Training_Loss: 0.5293,
# Batch number: 514, Training_Loss: 0.7755,
# Batch number: 515, Training_Loss: 0.5789,
# Batch number: 516, Training_Loss: 0.9797,
# Batch number: 517, Training_Loss: 1.0379,
# Batch number: 518, Training_Loss: 0.6335,
# Batch number: 519, Training_Loss: 0.9833,
# Batch number: 520, Training_Loss: 0.5475,
# Batch number: 521, Training_Loss: 0.9432,
# Batch number: 522, Training_Loss: 0.8258,
# Batch number: 523, Training_Loss: 0.7073,
# Batch number: 524, Training_Loss: 0.6510,
# Batch number: 525, Training_Loss: 0.8347,
# Batch number: 526, Training_Loss: 0.8654,
# Batch number: 527, Training_Loss: 0.6736,
# Batch number: 528, Training_Loss: 0.7322,
# Batch number: 529, Training_Loss: 0.6744,
# Batch number: 530, Training_Loss: 0.6608,
# Batch number: 531, Training_Loss: 0.7853,
# Batch number: 532, Training_Loss: 0.6634,
# Batch number: 533, Training_Loss: 0.8105,
# Batch number: 534, Training_Loss: 0.6708,
# Batch number: 535, Training_Loss: 0.8879,
# Batch number: 536, Training_Loss: 0.5696,
# Batch number: 537, Training_Loss: 1.0359,
# Batch number: 538, Training_Loss: 0.7481,
# Batch number: 539, Training_Loss: 1.0654,
# Batch number: 540, Training_Loss: 0.4880,
# Batch number: 541, Training_Loss: 0.8475,
# Batch number: 542, Training_Loss: 0.8940,
# Batch number: 543, Training_Loss: 0.7514,
# Batch number: 544, Training_Loss: 0.5112,
# Batch number: 545, Training_Loss: 0.6389,
# Batch number: 546, Training_Loss: 0.6403,
# Batch number: 547, Training_Loss: 0.7160,
# Batch number: 548, Training_Loss: 0.7142,
# Batch number: 549, Training_Loss: 0.5938,
# Batch number: 550, Training_Loss: 0.9504,
# Batch number: 551, Training_Loss: 0.9700,
# Batch number: 552, Training_Loss: 1.0549,
# Batch number: 553, Training_Loss: 1.0100,
# Batch number: 554, Training_Loss: 0.7722,
# Batch number: 555, Training_Loss: 0.6854,
# Batch number: 556, Training_Loss: 0.7726,
# Batch number: 557, Training_Loss: 0.7246,
# Batch number: 558, Training_Loss: 0.9236,
# Batch number: 559, Training_Loss: 1.0761,
# Batch number: 560, Training_Loss: 1.0535,
# Batch number: 561, Training_Loss: 0.8027,
# Batch number: 562, Training_Loss: 1.0087,
# Batch number: 563, Training_Loss: 0.7547,
# Batch number: 564, Training_Loss: 0.9409,
# Batch number: 565, Training_Loss: 0.9334,
# Batch number: 566, Training_Loss: 0.8840,
# Batch number: 567, Training_Loss: 0.7830,
# Batch number: 568, Training_Loss: 0.8157,
# Batch number: 569, Training_Loss: 0.7305,
# Batch number: 570, Training_Loss: 0.7412,
# Batch number: 571, Training_Loss: 0.8171,
# Batch number: 572, Training_Loss: 0.8385,
# Batch number: 573, Training_Loss: 0.8596,
# Batch number: 574, Training_Loss: 0.7416,
# Batch number: 575, Training_Loss: 0.8724,
# Batch number: 576, Training_Loss: 0.7666,
# Batch number: 577, Training_Loss: 0.7490,
# Batch number: 578, Training_Loss: 0.6228,
# Batch number: 579, Training_Loss: 0.8057,
# Batch number: 580, Training_Loss: 0.9348,
# Batch number: 581, Training_Loss: 0.8729,
# Batch number: 582, Training_Loss: 0.6624,
# Batch number: 583, Training_Loss: 0.7919,
# Batch number: 584, Training_Loss: 0.6309,
# Batch number: 585, Training_Loss: 0.8807,
# Batch number: 586, Training_Loss: 0.6163,
# Batch number: 587, Training_Loss: 0.7816,
# Batch number: 588, Training_Loss: 0.7001,
# Batch number: 589, Training_Loss: 0.9619,
# Batch number: 590, Training_Loss: 0.6239,
# Batch number: 591, Training_Loss: 0.6547,
# Batch number: 592, Training_Loss: 0.9605,
# Batch number: 593, Training_Loss: 0.7180,
# Batch number: 594, Training_Loss: 0.7028,
# Batch number: 595, Training_Loss: 0.7067,
# Batch number: 596, Training_Loss: 0.7395,
# Batch number: 597, Training_Loss: 0.7746,
# Batch number: 598, Training_Loss: 0.7344,
# Batch number: 599, Training_Loss: 0.8168,
# Batch number: 600, Training_Loss: 0.7696,
# Batch number: 601, Training_Loss: 0.5859,
# Batch number: 602, Training_Loss: 1.2507,
# Batch number: 603, Training_Loss: 0.6467,
# Batch number: 604, Training_Loss: 0.6812,
# Batch number: 605, Training_Loss: 0.6458,
# Batch number: 606, Training_Loss: 0.6370,
# Batch number: 607, Training_Loss: 0.7122,
# Batch number: 608, Training_Loss: 0.5894,
# Batch number: 609, Training_Loss: 0.6661,
# Batch number: 610, Training_Loss: 0.7533,
# Batch number: 611, Training_Loss: 0.4882,
# Batch number: 612, Training_Loss: 0.6813,
# Batch number: 613, Training_Loss: 0.8831,
# Batch number: 614, Training_Loss: 0.7058,
# Batch number: 615, Training_Loss: 0.5582,
# Batch number: 616, Training_Loss: 0.5266,
# Batch number: 617, Training_Loss: 0.4657,
# Batch number: 618, Training_Loss: 0.5999,
# Batch number: 619, Training_Loss: 0.3834,
# Batch number: 620, Training_Loss: 0.6994,
# Batch number: 621, Training_Loss: 0.6460,
# Batch number: 622, Training_Loss: 1.1408,
# Batch number: 623, Training_Loss: 0.5893,
# Batch number: 624, Training_Loss: 0.5343,
# Batch number: 625, Training_Loss: 0.6704,
# Batch number: 626, Training_Loss: 0.5356,
# Batch number: 627, Training_Loss: 1.5444,
# Batch number: 628, Training_Loss: 0.9349,
# Batch number: 629, Training_Loss: 0.8260,
# Batch number: 630, Training_Loss: 0.5432,
# Batch number: 631, Training_Loss: 0.5648,
# Batch number: 632, Training_Loss: 0.6590,
# Batch number: 633, Training_Loss: 0.4721,
# Batch number: 634, Training_Loss: 0.7253,
# Batch number: 635, Training_Loss: 0.6364,
# Batch number: 636, Training_Loss: 0.5528,
# Batch number: 637, Training_Loss: 0.6290,
# Batch number: 638, Training_Loss: 0.5818,
# Batch number: 639, Training_Loss: 0.7907,
# C:\Users\Akansh Maurya\anaconda3\lib\site-packages\ipykernel_launcher.py:43: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Test Batch number: 000, Test_Loss: 0.1240, Accuracy:1.00
# Test Batch number: 001, Test_Loss: 0.1473, Accuracy:1.00
# Test Batch number: 002, Test_Loss: 0.1827, Accuracy:1.00
# Test Batch number: 003, Test_Loss: 0.0639, Accuracy:1.00
# Test Batch number: 004, Test_Loss: 0.5606, Accuracy:0.94
# Test Batch number: 005, Test_Loss: 1.4905, Accuracy:0.83
# Test Batch number: 006, Test_Loss: 1.4997, Accuracy:0.74
# Test Batch number: 007, Test_Loss: 0.8699, Accuracy:0.73
# Test Batch number: 008, Test_Loss: 0.8149, Accuracy:0.74
# Test Batch number: 009, Test_Loss: 0.5611, Accuracy:0.76
# Test Batch number: 010, Test_Loss: 0.5218, Accuracy:0.78
# Test Batch number: 011, Test_Loss: 0.6032, Accuracy:0.80
# Test Batch number: 012, Test_Loss: 0.5789, Accuracy:0.81
# Test Batch number: 013, Test_Loss: 0.7902, Accuracy:0.77
# Test Batch number: 014, Test_Loss: 0.8291, Accuracy:0.73
# Test Batch number: 015, Test_Loss: 0.8313, Accuracy:0.69
# Test Batch number: 016, Test_Loss: 0.8454, Accuracy:0.66
# Test Batch number: 017, Test_Loss: 0.7239, Accuracy:0.65
# Epoch: 2/30
# Batch number: 000, Training_Loss: 0.6781,
# Batch number: 001, Training_Loss: 0.5578,
# Batch number: 002, Training_Loss: 1.0771,
# Batch number: 003, Training_Loss: 0.6293,
# Batch number: 004, Training_Loss: 0.8074,
# Batch number: 005, Training_Loss: 0.5538,
# Batch number: 006, Training_Loss: 0.5524,
# Batch number: 007, Training_Loss: 0.5194,
# Batch number: 008, Training_Loss: 0.7741,
# Batch number: 009, Training_Loss: 0.9006,
# Batch number: 010, Training_Loss: 0.5316,
# Batch number: 011, Training_Loss: 0.6797,
# Batch number: 012, Training_Loss: 0.7029,
# Batch number: 013, Training_Loss: 0.3503,
# Batch number: 014, Training_Loss: 0.4734,
# Batch number: 015, Training_Loss: 0.6027,
# Batch number: 016, Training_Loss: 0.5213,
# Batch number: 017, Training_Loss: 0.4406,
# Batch number: 018, Training_Loss: 0.7057,
# Batch number: 019, Training_Loss: 0.5854,
# Batch number: 020, Training_Loss: 0.5160,
# Batch number: 021, Training_Loss: 1.0112,
# Batch number: 022, Training_Loss: 0.4873,
# Batch number: 023, Training_Loss: 0.6989,
# Batch number: 024, Training_Loss: 0.6208,
# Batch number: 025, Training_Loss: 0.8472,
# Batch number: 026, Training_Loss: 0.7001,
# Batch number: 027, Training_Loss: 1.0933,
# Batch number: 028, Training_Loss: 0.4102,
# Batch number: 029, Training_Loss: 0.5556,
# Batch number: 030, Training_Loss: 0.6798,
# Batch number: 031, Training_Loss: 0.9660,
# Batch number: 032, Training_Loss: 0.5176,
# Batch number: 033, Training_Loss: 2.0055,
# Batch number: 034, Training_Loss: 0.6766,
# Batch number: 035, Training_Loss: 0.9930,
# Batch number: 036, Training_Loss: 1.4147,
# Batch number: 037, Training_Loss: 0.6791,
# Batch number: 038, Training_Loss: 1.1994,
# Batch number: 039, Training_Loss: 0.8265,
# Batch number: 040, Training_Loss: 0.9204,
# Batch number: 041, Training_Loss: 0.8251,
# Batch number: 042, Training_Loss: 0.7318,
# Batch number: 043, Training_Loss: 1.1410,
# Batch number: 044, Training_Loss: 0.6449,
# Batch number: 045, Training_Loss: 0.8118,
# Batch number: 046, Training_Loss: 1.2932,
# Batch number: 047, Training_Loss: 0.9302,
# Batch number: 048, Training_Loss: 0.9394,
# Batch number: 049, Training_Loss: 0.8900,
# Batch number: 050, Training_Loss: 0.6503,
# Batch number: 051, Training_Loss: 1.0513,
# Batch number: 052, Training_Loss: 0.8657,
# Batch number: 053, Training_Loss: 0.8920,
# Batch number: 054, Training_Loss: 0.9678,
# Batch number: 055, Training_Loss: 0.6229,
# Batch number: 056, Training_Loss: 0.7655,
# Batch number: 057, Training_Loss: 0.6968,
# Batch number: 058, Training_Loss: 0.8216,
# Batch number: 059, Training_Loss: 0.6895,
# Batch number: 060, Training_Loss: 0.7782,
# Batch number: 061, Training_Loss: 0.8064,
# Batch number: 062, Training_Loss: 0.7856,
# Batch number: 063, Training_Loss: 0.6858,
# Batch number: 064, Training_Loss: 0.8364,
# Batch number: 065, Training_Loss: 0.6348,
# Batch number: 066, Training_Loss: 0.6636,
# Batch number: 067, Training_Loss: 0.8043,
# Batch number: 068, Training_Loss: 0.7282,
# Batch number: 069, Training_Loss: 0.5965,
# Batch number: 070, Training_Loss: 0.6793,
# Batch number: 071, Training_Loss: 0.6503,
# Batch number: 072, Training_Loss: 0.7667,
# Batch number: 073, Training_Loss: 0.6086,
# Batch number: 074, Training_Loss: 0.5673,
# Batch number: 075, Training_Loss: 1.4070,
# Batch number: 076, Training_Loss: 0.6727,
# Batch number: 077, Training_Loss: 0.8099,
# Batch number: 078, Training_Loss: 0.6906,
# Batch number: 079, Training_Loss: 0.6564,
# Batch number: 080, Training_Loss: 0.5903,
# Batch number: 081, Training_Loss: 0.9354,
# Batch number: 082, Training_Loss: 0.6401,
# Batch number: 083, Training_Loss: 0.6996,
# Batch number: 084, Training_Loss: 0.8026,
# Batch number: 085, Training_Loss: 0.8029,
# Batch number: 086, Training_Loss: 0.4373,
# Batch number: 087, Training_Loss: 0.7984,
# Batch number: 088, Training_Loss: 0.8409,
# Batch number: 089, Training_Loss: 0.6186,
# Batch number: 090, Training_Loss: 0.7357,
# Batch number: 091, Training_Loss: 0.8665,
# Batch number: 092, Training_Loss: 0.6387,
# Batch number: 093, Training_Loss: 0.5237,
# Batch number: 094, Training_Loss: 0.6414,
# Batch number: 095, Training_Loss: 0.8368,
# Batch number: 096, Training_Loss: 0.6463,
# Batch number: 097, Training_Loss: 0.7070,
# Batch number: 098, Training_Loss: 0.4914,
# Batch number: 099, Training_Loss: 0.5255,
# Batch number: 100, Training_Loss: 0.5565,
# Batch number: 101, Training_Loss: 0.4625,
# Batch number: 102, Training_Loss: 0.6783,
# Batch number: 103, Training_Loss: 0.9047,
# Batch number: 104, Training_Loss: 0.7968,
# Batch number: 105, Training_Loss: 0.5931,
# Batch number: 106, Training_Loss: 0.6858,
# Batch number: 107, Training_Loss: 1.1635,
# Batch number: 108, Training_Loss: 0.4977,
# Batch number: 109, Training_Loss: 0.7130,
# Batch number: 110, Training_Loss: 0.7142,
# Batch number: 111, Training_Loss: 0.5327,
# Batch number: 112, Training_Loss: 0.5977,
# Batch number: 113, Training_Loss: 0.5065,
# Batch number: 114, Training_Loss: 0.5614,
# Batch number: 115, Training_Loss: 0.7558,
# Batch number: 116, Training_Loss: 0.4460,
# Batch number: 117, Training_Loss: 0.8450,
# Batch number: 118, Training_Loss: 0.6664,
# Batch number: 119, Training_Loss: 0.5111,
# Batch number: 120, Training_Loss: 1.1971,
# Batch number: 121, Training_Loss: 0.6598,
# Batch number: 122, Training_Loss: 0.4842,
# Batch number: 123, Training_Loss: 0.6700,
# Batch number: 124, Training_Loss: 0.5445,
# Batch number: 125, Training_Loss: 0.6266,
# Batch number: 126, Training_Loss: 0.8411,
# Batch number: 127, Training_Loss: 1.3159,
# Batch number: 128, Training_Loss: 0.6881,
# Batch number: 129, Training_Loss: 0.5746,
# Batch number: 130, Training_Loss: 0.4566,
# Batch number: 131, Training_Loss: 0.4479,
# Batch number: 132, Training_Loss: 0.5026,
# Batch number: 133, Training_Loss: 0.5429,
# Batch number: 134, Training_Loss: 0.5168,
# Batch number: 135, Training_Loss: 0.6894,
# Batch number: 136, Training_Loss: 0.6502,
# Batch number: 137, Training_Loss: 0.5188,
# Batch number: 138, Training_Loss: 0.4400,
# Batch number: 139, Training_Loss: 0.7282,
# Batch number: 140, Training_Loss: 0.6616,
# Batch number: 141, Training_Loss: 0.9483,
# Batch number: 142, Training_Loss: 0.6384,
# Batch number: 143, Training_Loss: 0.3575,
# Batch number: 144, Training_Loss: 0.4654,
# Batch number: 145, Training_Loss: 0.3968,
# Batch number: 146, Training_Loss: 0.6273,
# Batch number: 147, Training_Loss: 0.5199,
# Batch number: 148, Training_Loss: 0.7436,
# Batch number: 149, Training_Loss: 0.4338,
# Batch number: 150, Training_Loss: 0.5564,
# Batch number: 151, Training_Loss: 0.4112,
# Batch number: 152, Training_Loss: 0.5911,
# Batch number: 153, Training_Loss: 0.5266,
# Batch number: 154, Training_Loss: 0.5999,
# Batch number: 155, Training_Loss: 0.3657,
# Batch number: 156, Training_Loss: 0.5856,
# Batch number: 157, Training_Loss: 0.4755,
# Batch number: 158, Training_Loss: 0.5596,
# Batch number: 159, Training_Loss: 0.5981,
# Batch number: 160, Training_Loss: 0.7906,
# Batch number: 161, Training_Loss: 0.3838,
# Batch number: 162, Training_Loss: 0.5724,
# Batch number: 163, Training_Loss: 0.8445,
# Batch number: 164, Training_Loss: 0.4036,
# Batch number: 165, Training_Loss: 0.3609,
# Batch number: 166, Training_Loss: 0.4692,
# Batch number: 167, Training_Loss: 0.6572,
# Batch number: 168, Training_Loss: 0.6853,
# Batch number: 169, Training_Loss: 0.5726,
# Batch number: 170, Training_Loss: 0.3749,
# Batch number: 171, Training_Loss: 1.0605,
# Batch number: 172, Training_Loss: 0.7287,
# Batch number: 173, Training_Loss: 1.4951,
# Batch number: 174, Training_Loss: 0.5177,
# Batch number: 175, Training_Loss: 0.5317,
# Batch number: 176, Training_Loss: 1.0284,
# Batch number: 177, Training_Loss: 0.5294,
# Batch number: 178, Training_Loss: 0.4437,
# Batch number: 179, Training_Loss: 0.4320,
# Batch number: 180, Training_Loss: 0.4351,
# Batch number: 181, Training_Loss: 0.5043,
# Batch number: 182, Training_Loss: 0.7975,
# Batch number: 183, Training_Loss: 1.0709,
# Batch number: 184, Training_Loss: 0.6843,
# Batch number: 185, Training_Loss: 0.7943,
# Batch number: 186, Training_Loss: 0.8329,
# Batch number: 187, Training_Loss: 0.8307,
# Batch number: 188, Training_Loss: 0.6557,
# Batch number: 189, Training_Loss: 0.4919,
# Batch number: 190, Training_Loss: 0.5769,
# Batch number: 191, Training_Loss: 0.7204,
# Batch number: 192, Training_Loss: 0.5081,
# Batch number: 193, Training_Loss: 0.4375,
# Batch number: 194, Training_Loss: 0.6983,
# Batch number: 195, Training_Loss: 0.4468,
# Batch number: 196, Training_Loss: 0.7910,
# Batch number: 197, Training_Loss: 0.4481,
# Batch number: 198, Training_Loss: 0.4002,
# Batch number: 199, Training_Loss: 0.8279,
# Batch number: 200, Training_Loss: 0.4939,
# Batch number: 201, Training_Loss: 0.5459,
# Batch number: 202, Training_Loss: 0.5972,
# Batch number: 203, Training_Loss: 0.7225,
# Batch number: 204, Training_Loss: 0.5027,
# Batch number: 205, Training_Loss: 0.6577,
# Batch number: 206, Training_Loss: 0.5286,
# Batch number: 207, Training_Loss: 0.5677,
# Batch number: 208, Training_Loss: 0.4877,
# Batch number: 209, Training_Loss: 0.4137,
# Batch number: 210, Training_Loss: 0.3710,
# Batch number: 211, Training_Loss: 0.5968,
# Batch number: 212, Training_Loss: 0.4992,
# Batch number: 213, Training_Loss: 0.4705,
# Batch number: 214, Training_Loss: 0.4739,
# Batch number: 215, Training_Loss: 0.6020,
# Batch number: 216, Training_Loss: 0.5459,
# Batch number: 217, Training_Loss: 0.2895,
# Batch number: 218, Training_Loss: 0.5010,
# Batch number: 219, Training_Loss: 0.4616,
# Batch number: 220, Training_Loss: 0.4555,
# Batch number: 221, Training_Loss: 0.6780,
# Batch number: 222, Training_Loss: 1.0743,
# Batch number: 223, Training_Loss: 0.7937,
# Batch number: 224, Training_Loss: 0.5633,
# Batch number: 225, Training_Loss: 0.5664,
# Batch number: 226, Training_Loss: 0.6836,
# Batch number: 227, Training_Loss: 0.6147,
# Batch number: 228, Training_Loss: 0.7741,
# Batch number: 229, Training_Loss: 0.5411,
# Batch number: 230, Training_Loss: 0.4937,
# Batch number: 231, Training_Loss: 0.9179,
# Batch number: 232, Training_Loss: 0.5313,
# Batch number: 233, Training_Loss: 0.8124,
# Batch number: 234, Training_Loss: 0.5778,
# Batch number: 235, Training_Loss: 0.4500,
# Batch number: 236, Training_Loss: 0.5191,
# Batch number: 237, Training_Loss: 0.2868,
# Batch number: 238, Training_Loss: 0.7259,
# Batch number: 239, Training_Loss: 0.5607,
# Batch number: 240, Training_Loss: 0.3982,
# Batch number: 241, Training_Loss: 0.6913,
# Batch number: 242, Training_Loss: 0.6287,
# Batch number: 243, Training_Loss: 0.6214,
# Batch number: 244, Training_Loss: 0.7424,
# Batch number: 245, Training_Loss: 0.5423,
# Batch number: 246, Training_Loss: 0.6176,
# Batch number: 247, Training_Loss: 0.5449,
# Batch number: 248, Training_Loss: 0.4679,
# Batch number: 249, Training_Loss: 0.5708,
# Batch number: 250, Training_Loss: 0.4041,
# Batch number: 251, Training_Loss: 0.6502,
# Batch number: 252, Training_Loss: 0.6164,
# Batch number: 253, Training_Loss: 0.4373,
# Batch number: 254, Training_Loss: 1.1845,
# Batch number: 255, Training_Loss: 0.9619,
# Batch number: 256, Training_Loss: 0.4903,
# Batch number: 257, Training_Loss: 0.8689,
# Batch number: 258, Training_Loss: 0.7164,
# Batch number: 259, Training_Loss: 0.7430,
# Batch number: 260, Training_Loss: 1.0168,
# Batch number: 261, Training_Loss: 0.5857,
# Batch number: 262, Training_Loss: 0.5274,
# Batch number: 263, Training_Loss: 0.5446,
# Batch number: 264, Training_Loss: 0.5622,
# Batch number: 265, Training_Loss: 1.1757,
# Batch number: 266, Training_Loss: 0.4916,
# Batch number: 267, Training_Loss: 0.4409,
# Batch number: 268, Training_Loss: 0.4160,
# Batch number: 269, Training_Loss: 1.2063,
# Batch number: 270, Training_Loss: 0.9608,
# Batch number: 271, Training_Loss: 0.4558,
# Batch number: 272, Training_Loss: 0.5786,
# Batch number: 273, Training_Loss: 0.5117,
# Batch number: 274, Training_Loss: 0.5140,
# Batch number: 275, Training_Loss: 0.6014,
# Batch number: 276, Training_Loss: 1.0217,
# Batch number: 277, Training_Loss: 0.7274,
# Batch number: 278, Training_Loss: 0.7143,
# Batch number: 279, Training_Loss: 0.4946,
# Batch number: 280, Training_Loss: 0.3866,
# Batch number: 281, Training_Loss: 0.4759,
# Batch number: 282, Training_Loss: 0.4373,
# Batch number: 283, Training_Loss: 0.5016,
# Batch number: 284, Training_Loss: 0.9653,
# Batch number: 285, Training_Loss: 0.7368,
# Batch number: 286, Training_Loss: 1.0209,
# Batch number: 287, Training_Loss: 0.6052,
# Batch number: 288, Training_Loss: 0.6782,
# Batch number: 289, Training_Loss: 0.4961,
# Batch number: 290, Training_Loss: 0.3998,
# Batch number: 291, Training_Loss: 0.7010,
# Batch number: 292, Training_Loss: 0.6071,
# Batch number: 293, Training_Loss: 1.2648,
# Batch number: 294, Training_Loss: 0.5454,
# Batch number: 295, Training_Loss: 0.7096,
# Batch number: 296, Training_Loss: 0.5769,
# Batch number: 297, Training_Loss: 0.6842,
# Batch number: 298, Training_Loss: 0.7991,
# Batch number: 299, Training_Loss: 0.4448,
# Batch number: 300, Training_Loss: 0.6782,
# Batch number: 301, Training_Loss: 0.3906,
# Batch number: 302, Training_Loss: 0.5468,
# Batch number: 303, Training_Loss: 0.5646,
# Batch number: 304, Training_Loss: 0.4117,
# Batch number: 305, Training_Loss: 0.5908,
# Batch number: 306, Training_Loss: 0.6996,
# Batch number: 307, Training_Loss: 0.5127,
# Batch number: 308, Training_Loss: 0.3737,
# Batch number: 309, Training_Loss: 0.6168,
# Batch number: 310, Training_Loss: 0.3315,
# Batch number: 311, Training_Loss: 0.3933,
# Batch number: 312, Training_Loss: 0.5340,
# Batch number: 313, Training_Loss: 0.3920,
# Batch number: 314, Training_Loss: 0.3694,
# Batch number: 315, Training_Loss: 0.5396,
# Batch number: 316, Training_Loss: 0.6253,
# Batch number: 317, Training_Loss: 0.5936,
# Batch number: 318, Training_Loss: 0.8070,
# Batch number: 319, Training_Loss: 0.4901,
# Batch number: 320, Training_Loss: 0.5822,
# Batch number: 321, Training_Loss: 0.6046,
# Batch number: 322, Training_Loss: 0.3299,
# Batch number: 323, Training_Loss: 0.4858,
# Batch number: 324, Training_Loss: 0.3999,
# Batch number: 325, Training_Loss: 1.0720,
# Batch number: 326, Training_Loss: 1.2700,
# Batch number: 327, Training_Loss: 0.4789,
# Batch number: 328, Training_Loss: 0.3734,
# Batch number: 329, Training_Loss: 0.3848,
# Batch number: 330, Training_Loss: 0.3485,
# Batch number: 331, Training_Loss: 0.4647,
# Batch number: 332, Training_Loss: 0.4806,
# Batch number: 333, Training_Loss: 0.5867,
# Batch number: 334, Training_Loss: 0.9565,
# Batch number: 335, Training_Loss: 0.3783,
# Batch number: 336, Training_Loss: 0.2884,
# Batch number: 337, Training_Loss: 0.8780,
# Batch number: 338, Training_Loss: 0.5954,
# Batch number: 339, Training_Loss: 0.7200,
# Batch number: 340, Training_Loss: 0.4021,
# Batch number: 341, Training_Loss: 0.7222,
# Batch number: 342, Training_Loss: 0.9712,
# Batch number: 343, Training_Loss: 0.5074,
# Batch number: 344, Training_Loss: 0.4596,
# Batch number: 345, Training_Loss: 0.5765,
# Batch number: 346, Training_Loss: 0.6849,
# Batch number: 347, Training_Loss: 0.4459,
# Batch number: 348, Training_Loss: 0.6773,
# Batch number: 349, Training_Loss: 0.7124,
# Batch number: 350, Training_Loss: 0.7169,
# Batch number: 351, Training_Loss: 0.7091,
# Batch number: 352, Training_Loss: 0.9545,
# Batch number: 353, Training_Loss: 0.6656,
# Batch number: 354, Training_Loss: 0.5216,
# Batch number: 355, Training_Loss: 0.7744,
# Batch number: 356, Training_Loss: 0.4078,
# Batch number: 357, Training_Loss: 0.8204,
# Batch number: 358, Training_Loss: 0.5472,
# Batch number: 359, Training_Loss: 0.4262,
# Batch number: 360, Training_Loss: 0.5481,
# Batch number: 361, Training_Loss: 0.4079,
# Batch number: 362, Training_Loss: 0.6743,
# Batch number: 363, Training_Loss: 0.4668,
# Batch number: 364, Training_Loss: 0.2952,
# Batch number: 365, Training_Loss: 0.9926,
# Batch number: 366, Training_Loss: 0.5906,
# Batch number: 367, Training_Loss: 1.0952,
# Batch number: 368, Training_Loss: 0.5165,
# Batch number: 369, Training_Loss: 0.3381,
# Batch number: 370, Training_Loss: 0.5103,
# Batch number: 371, Training_Loss: 0.5626,
# Batch number: 372, Training_Loss: 0.2794,
# Batch number: 373, Training_Loss: 1.4873,
# Batch number: 374, Training_Loss: 0.6565,
# Batch number: 375, Training_Loss: 0.4514,
# Batch number: 376, Training_Loss: 0.4089,
# Batch number: 377, Training_Loss: 0.3332,
# Batch number: 378, Training_Loss: 0.6615,
# Batch number: 379, Training_Loss: 0.4058,
# Batch number: 380, Training_Loss: 0.6506,
# Batch number: 381, Training_Loss: 0.4609,
# Batch number: 382, Training_Loss: 0.2665,
# Batch number: 383, Training_Loss: 0.4183,
# Batch number: 384, Training_Loss: 0.3582,
# Batch number: 385, Training_Loss: 0.2308,
# Batch number: 386, Training_Loss: 1.0765,
# Batch number: 387, Training_Loss: 0.4408,
# Batch number: 388, Training_Loss: 0.2796,
# Batch number: 389, Training_Loss: 0.2489,
# Batch number: 390, Training_Loss: 0.5105,
# Batch number: 391, Training_Loss: 0.3407,
# Batch number: 392, Training_Loss: 0.5277,
# Batch number: 393, Training_Loss: 0.7146,
# Batch number: 394, Training_Loss: 0.4920,
# Batch number: 395, Training_Loss: 0.4216,
# Batch number: 396, Training_Loss: 0.6482,
# Batch number: 397, Training_Loss: 0.5305,
# Batch number: 398, Training_Loss: 0.2165,
# Batch number: 399, Training_Loss: 0.6095,
# Batch number: 400, Training_Loss: 0.3283,
# Batch number: 401, Training_Loss: 0.1603,
# Batch number: 402, Training_Loss: 0.5682,
# Batch number: 403, Training_Loss: 0.3578,
# Batch number: 404, Training_Loss: 0.4887,
# Batch number: 405, Training_Loss: 0.5283,
# Batch number: 406, Training_Loss: 0.8263,
# Batch number: 407, Training_Loss: 0.3771,
# Batch number: 408, Training_Loss: 0.7758,
# Batch number: 409, Training_Loss: 0.1826,
# Batch number: 410, Training_Loss: 0.2756,
# Batch number: 411, Training_Loss: 0.4897,
# Batch number: 412, Training_Loss: 0.3305,
# Batch number: 413, Training_Loss: 1.2265,
# Batch number: 414, Training_Loss: 0.4811,
# Batch number: 415, Training_Loss: 0.1905,
# Batch number: 416, Training_Loss: 0.5511,
# Batch number: 417, Training_Loss: 0.5048,
# Batch number: 418, Training_Loss: 0.7848,
# Batch number: 419, Training_Loss: 0.7723,
# Batch number: 420, Training_Loss: 0.4315,
# Batch number: 421, Training_Loss: 0.6125,
# Batch number: 422, Training_Loss: 1.6710,
# Batch number: 423, Training_Loss: 0.6374,
# Batch number: 424, Training_Loss: 0.5468,
# Batch number: 425, Training_Loss: 0.8641,
# Batch number: 426, Training_Loss: 0.6717,
# Batch number: 427, Training_Loss: 0.5005,
# Batch number: 428, Training_Loss: 0.6565,
# Batch number: 429, Training_Loss: 0.4105,
# Batch number: 430, Training_Loss: 0.8105,
# Batch number: 431, Training_Loss: 0.8058,
# Batch number: 432, Training_Loss: 0.8127,
# Batch number: 433, Training_Loss: 0.4189,
# Batch number: 434, Training_Loss: 0.5572,
# Batch number: 435, Training_Loss: 0.4211,
# Batch number: 436, Training_Loss: 0.4064,
# Batch number: 437, Training_Loss: 0.6356,
# Batch number: 438, Training_Loss: 0.7993,
# Batch number: 439, Training_Loss: 1.0372,
# Batch number: 440, Training_Loss: 0.4901,
# Batch number: 441, Training_Loss: 0.8317,
# Batch number: 442, Training_Loss: 0.3596,
# Batch number: 443, Training_Loss: 0.7132,
# Batch number: 444, Training_Loss: 0.6318,
# Batch number: 445, Training_Loss: 0.6267,
# Batch number: 446, Training_Loss: 0.3443,
# Batch number: 447, Training_Loss: 0.4422,
# Batch number: 448, Training_Loss: 0.8684,
# Batch number: 449, Training_Loss: 0.3702,
# Batch number: 450, Training_Loss: 0.4917,
# Batch number: 451, Training_Loss: 0.3215,
# Batch number: 452, Training_Loss: 0.2984,
# Batch number: 453, Training_Loss: 0.4990,
# Batch number: 454, Training_Loss: 1.1308,
# Batch number: 455, Training_Loss: 0.3881,
# Batch number: 456, Training_Loss: 0.5345,
# Batch number: 457, Training_Loss: 0.8497,
# Batch number: 458, Training_Loss: 0.8408,
# Batch number: 459, Training_Loss: 0.5539,
# Batch number: 460, Training_Loss: 0.6196,
# Batch number: 461, Training_Loss: 0.6049,
# Batch number: 462, Training_Loss: 0.5628,
# Batch number: 463, Training_Loss: 0.4635,
# Batch number: 464, Training_Loss: 0.3187,
# Batch number: 465, Training_Loss: 0.4840,
# Batch number: 466, Training_Loss: 0.5170,
# Batch number: 467, Training_Loss: 0.8529,
# Batch number: 468, Training_Loss: 0.8247,
# Batch number: 469, Training_Loss: 0.4649,
# Batch number: 470, Training_Loss: 0.5706,
# Batch number: 471, Training_Loss: 0.8145,
# Batch number: 472, Training_Loss: 0.4440,
# ...
# Batch number: 284, Training_Loss: 0.7895,
# Batch number: 285, Training_Loss: 0.0574,
# Batch number: 286, Training_Loss: 0.0840,
# Batch number: 287, Training_Loss: 0.0698,
# Batch number: 288, Training_Loss: 0.0068,
# Batch number: 289, Training_Loss: 0.0142,
# Batch number: 290, Training_Loss: 0.0014,
# Batch number: 291, Training_Loss: 0.0302,
# Batch number: 292, Training_Loss: 0.3406,
# Batch number: 293, Training_Loss: 0.0133,
# Batch number: 294, Training_Loss: 0.0349,
# Batch number: 295, Training_Loss: 0.0204,
# Batch number: 296, Training_Loss: 0.0017,
# Batch number: 297, Training_Loss: 0.0696,
# Batch number: 298, Training_Loss: 0.0018,
# Batch number: 299, Training_Loss: 0.0028,
# Batch number: 300, Training_Loss: 0.0002,
# Batch number: 301, Training_Loss: 0.0075,
# Batch number: 302, Training_Loss: 0.0014,
# Batch number: 303, Training_Loss: 0.0714,
# Batch number: 304, Training_Loss: 0.0420,
# Batch number: 305, Training_Loss: 0.0073,
# Batch number: 306, Training_Loss: 0.1104,
# Batch number: 307, Training_Loss: 0.0945,
# Batch number: 308, Training_Loss: 0.1699,
# Batch number: 309, Training_Loss: 0.1721,
# Batch number: 310, Training_Loss: 0.1428,
# Batch number: 311, Training_Loss: 0.0029,
# Batch number: 312, Training_Loss: 0.1707,
# Batch number: 313, Training_Loss: 0.1984,
# Batch number: 314, Training_Loss: 0.0358,
# Batch number: 315, Training_Loss: 0.0118,
# Batch number: 316, Training_Loss: 0.2792,
# Batch number: 317, Training_Loss: 0.0001,
# Batch number: 318, Training_Loss: 0.0010,
# Batch number: 319, Training_Loss: 0.0083,
# Batch number: 320, Training_Loss: 0.0030,
# Batch number: 321, Training_Loss: 0.0024,
# Batch number: 322, Training_Loss: 0.0437,
# Batch number: 323, Training_Loss: 0.0617,
# Batch number: 324, Training_Loss: 0.0034,
# Batch number: 325, Training_Loss: 0.1030,
# Batch number: 326, Training_Loss: 0.1069,
# Batch number: 327, Training_Loss: 0.0047,
# Batch number: 328, Training_Loss: 0.0082,
# Batch number: 329, Training_Loss: 0.0000,
# Batch number: 330, Training_Loss: 0.5522,
# Batch number: 331, Training_Loss: 0.0180,
# Batch number: 332, Training_Loss: 0.0028,
# Batch number: 333, Training_Loss: 0.0004,
# Batch number: 334, Training_Loss: 0.0365,
# Batch number: 335, Training_Loss: 0.0101,
# Batch number: 336, Training_Loss: 0.1461,
# Batch number: 337, Training_Loss: 0.0028,
# Batch number: 338, Training_Loss: 0.0004,
# Batch number: 339, Training_Loss: 0.0819,
# Batch number: 340, Training_Loss: 0.0413,
# Batch number: 341, Training_Loss: 0.0006,
# Batch number: 342, Training_Loss: 0.0002,
# Batch number: 343, Training_Loss: 0.2094,
# Batch number: 344, Training_Loss: 0.0030,
# Batch number: 345, Training_Loss: 0.2603,
# Batch number: 346, Training_Loss: 0.0046,
# Batch number: 347, Training_Loss: 0.0029,
# Batch number: 348, Training_Loss: 0.3046,
# Batch number: 349, Training_Loss: 0.0149,
# Batch number: 350, Training_Loss: 0.0008,
# Batch number: 351, Training_Loss: 0.0562,
# Batch number: 352, Training_Loss: 0.0170,
# Batch number: 353, Training_Loss: 0.0712,
# Batch number: 354, Training_Loss: 0.0148,
# Batch number: 355, Training_Loss: 0.1005,
# Batch number: 356, Training_Loss: 0.0013,
# Batch number: 357, Training_Loss: 0.0416,
# Batch number: 358, Training_Loss: 0.0192,
# Batch number: 359, Training_Loss: 0.0014,
# Batch number: 360, Training_Loss: 0.1033,
# Batch number: 361, Training_Loss: 0.0087,
# Batch number: 362, Training_Loss: 0.0199,
# Batch number: 363, Training_Loss: 0.2466,
# Batch number: 364, Training_Loss: 0.0953,
# Batch number: 365, Training_Loss: 0.5474,
# Batch number: 366, Training_Loss: 0.4700,
# Batch number: 367, Training_Loss: 0.0111,
# Batch number: 368, Training_Loss: 0.0491,
# Batch number: 369, Training_Loss: 0.0037,
# Batch number: 370, Training_Loss: 0.1009,
# Batch number: 371, Training_Loss: 0.0184,
# Batch number: 372, Training_Loss: 0.0427,
# Batch number: 373, Training_Loss: 0.0385,
# Batch number: 374, Training_Loss: 0.0032,
# Batch number: 375, Training_Loss: 0.0071,
# Batch number: 376, Training_Loss: 0.0111,
# Batch number: 377, Training_Loss: 0.0076,
# Batch number: 378, Training_Loss: 0.0111,
# Batch number: 379, Training_Loss: 0.0049,
# Batch number: 380, Training_Loss: 0.1311,
# Batch number: 381, Training_Loss: 0.0037,
# Batch number: 382, Training_Loss: 0.0010,
# Batch number: 383, Training_Loss: 0.0607,
# Batch number: 384, Training_Loss: 0.0310,
# Batch number: 385, Training_Loss: 0.0009,
# Batch number: 386, Training_Loss: 0.0511,
# Batch number: 387, Training_Loss: 0.0317,
# Batch number: 388, Training_Loss: 0.0976,
# Batch number: 389, Training_Loss: 0.0021,
# Batch number: 390, Training_Loss: 0.0086,
# Batch number: 391, Training_Loss: 0.0149,
# Batch number: 392, Training_Loss: 0.5338,
# Batch number: 393, Training_Loss: 0.0037,
# Batch number: 394, Training_Loss: 0.0458,
# Batch number: 395, Training_Loss: 0.0070,
# Batch number: 396, Training_Loss: 0.0010,
# Batch number: 397, Training_Loss: 0.0512,
# Batch number: 398, Training_Loss: 0.0072,
# Batch number: 399, Training_Loss: 0.1039,
# Batch number: 400, Training_Loss: 0.0278,
# Batch number: 401, Training_Loss: 0.0435,
# Batch number: 402, Training_Loss: 0.0006,
# Batch number: 403, Training_Loss: 0.0670,
# Batch number: 404, Training_Loss: 0.2475,
# Batch number: 405, Training_Loss: 0.0516,
# Batch number: 406, Training_Loss: 0.0368,
# Batch number: 407, Training_Loss: 0.0209,
# Batch number: 408, Training_Loss: 0.0012,
# Batch number: 409, Training_Loss: 0.0004,
# Batch number: 410, Training_Loss: 0.0868,
# Batch number: 411, Training_Loss: 0.0088,
# Batch number: 412, Training_Loss: 0.0029,
# Batch number: 413, Training_Loss: 0.0279,
# Batch number: 414, Training_Loss: 0.0138,
# Batch number: 415, Training_Loss: 0.0024,
# Batch number: 416, Training_Loss: 0.0928,
# Batch number: 417, Training_Loss: 0.0026,
# Batch number: 418, Training_Loss: 0.4383,
# Batch number: 419, Training_Loss: 0.0101,
# Batch number: 420, Training_Loss: 0.0024,
# Batch number: 421, Training_Loss: 0.0065,
# Batch number: 422, Training_Loss: 0.0092,
# Batch number: 423, Training_Loss: 0.0056,
# Batch number: 424, Training_Loss: 0.1469,
# Batch number: 425, Training_Loss: 0.2326,
# Batch number: 426, Training_Loss: 0.0155,
# Batch number: 427, Training_Loss: 0.0152,
# Batch number: 428, Training_Loss: 0.0006,
# Batch number: 429, Training_Loss: 0.0088,
# Batch number: 430, Training_Loss: 0.0615,
# Batch number: 431, Training_Loss: 0.0025,
# Batch number: 432, Training_Loss: 0.0008,
# Batch number: 433, Training_Loss: 0.0037,
# Batch number: 434, Training_Loss: 0.1646,
# Batch number: 435, Training_Loss: 0.0798,
# Batch number: 436, Training_Loss: 0.0002,
# Batch number: 437, Training_Loss: 0.0402,
# Batch number: 438, Training_Loss: 0.0049,
# Batch number: 439, Training_Loss: 0.2372,
# Batch number: 440, Training_Loss: 0.0002,
# Batch number: 441, Training_Loss: 0.0075,
# Batch number: 442, Training_Loss: 0.0173,
# Batch number: 443, Training_Loss: 0.0025,
# Batch number: 444, Training_Loss: 0.0045,
# Batch number: 445, Training_Loss: 0.0695,
# Batch number: 446, Training_Loss: 0.2516,
# Batch number: 447, Training_Loss: 0.0268,
# Batch number: 448, Training_Loss: 0.0018,
# Batch number: 449, Training_Loss: 0.0625,
# Batch number: 450, Training_Loss: 0.0110,
# Batch number: 451, Training_Loss: 0.0018,
# Batch number: 452, Training_Loss: 0.0038,
# Batch number: 453, Training_Loss: 0.0004,
# Batch number: 454, Training_Loss: 0.2640,
# Batch number: 455, Training_Loss: 0.0150,
# Batch number: 456, Training_Loss: 0.0099,
# Batch number: 457, Training_Loss: 0.0034,
# Batch number: 458, Training_Loss: 0.0685,
# Batch number: 459, Training_Loss: 0.0029,
# Batch number: 460, Training_Loss: 0.0007,
# Batch number: 461, Training_Loss: 0.0002,
# Batch number: 462, Training_Loss: 0.0042,
# Batch number: 463, Training_Loss: 0.0046,
# Batch number: 464, Training_Loss: 0.0114,
# Batch number: 465, Training_Loss: 0.1753,
# Batch number: 466, Training_Loss: 0.0014,
# Batch number: 467, Training_Loss: 0.0013,
# Batch number: 468, Training_Loss: 0.1436,
# Batch number: 469, Training_Loss: 0.0122,
# Batch number: 470, Training_Loss: 0.0109,
# Batch number: 471, Training_Loss: 0.0013,
# Batch number: 472, Training_Loss: 0.0002,
# Batch number: 473, Training_Loss: 0.0004,
# Batch number: 474, Training_Loss: 0.0414,
# Batch number: 475, Training_Loss: 0.0863,
# Batch number: 476, Training_Loss: 0.0008,
# Batch number: 477, Training_Loss: 0.0007,
# Batch number: 478, Training_Loss: 0.0445,
# Batch number: 479, Training_Loss: 0.0188,
# Batch number: 480, Training_Loss: 0.0089,
# Batch number: 481, Training_Loss: 0.0424,
# Batch number: 482, Training_Loss: 0.0067,
# Batch number: 483, Training_Loss: 0.0032,
# Batch number: 484, Training_Loss: 0.0795,
# Batch number: 485, Training_Loss: 0.0038,
# Batch number: 486, Training_Loss: 0.0118,
# Batch number: 487, Training_Loss: 0.0040,
# Batch number: 488, Training_Loss: 0.0140,
# Batch number: 489, Training_Loss: 0.0017,
# Batch number: 490, Training_Loss: 0.0004,
# Batch number: 491, Training_Loss: 0.0072,
# Batch number: 492, Training_Loss: 0.0003,
# Batch number: 493, Training_Loss: 0.0008,
# Batch number: 494, Training_Loss: 0.1357,
# Batch number: 495, Training_Loss: 0.0009,
# Batch number: 496, Training_Loss: 0.0099,
# Batch number: 497, Training_Loss: 0.0307,
# Batch number: 498, Training_Loss: 0.0098,
# Batch number: 499, Training_Loss: 0.0042,
# Batch number: 500, Training_Loss: 0.0038,
# Batch number: 501, Training_Loss: 0.0009,
# Batch number: 502, Training_Loss: 0.0076,
# Batch number: 503, Training_Loss: 0.1140,
# Batch number: 504, Training_Loss: 0.0394,
# Batch number: 505, Training_Loss: 0.1992,
# Batch number: 506, Training_Loss: 0.0009,
# Batch number: 507, Training_Loss: 0.0048,
# Batch number: 508, Training_Loss: 0.0076,
# Batch number: 509, Training_Loss: 0.0048,
# Batch number: 510, Training_Loss: 0.0004,
# Batch number: 511, Training_Loss: 0.3815,
# Batch number: 512, Training_Loss: 0.0049,
# Batch number: 513, Training_Loss: 0.1979,
# Batch number: 514, Training_Loss: 0.0068,
# Batch number: 515, Training_Loss: 0.0630,
# Batch number: 516, Training_Loss: 0.0034,
# Batch number: 517, Training_Loss: 0.2572,
# Batch number: 518, Training_Loss: 0.1040,
# Batch number: 519, Training_Loss: 0.0042,
# Batch number: 520, Training_Loss: 0.0054,
# Batch number: 521, Training_Loss: 0.8717,
# Batch number: 522, Training_Loss: 0.0030,
# Batch number: 523, Training_Loss: 0.0049,
# Batch number: 524, Training_Loss: 0.0090,
# Batch number: 525, Training_Loss: 0.5467,
# Batch number: 526, Training_Loss: 0.0401,
# Batch number: 527, Training_Loss: 0.0217,
# Batch number: 528, Training_Loss: 0.0217,
# Batch number: 529, Training_Loss: 0.0068,
# Batch number: 530, Training_Loss: 0.0065,
# Batch number: 531, Training_Loss: 0.0791,
# Batch number: 532, Training_Loss: 0.0486,
# Batch number: 533, Training_Loss: 0.0385,
# Batch number: 534, Training_Loss: 0.0155,
# Batch number: 535, Training_Loss: 0.0366,
# Batch number: 536, Training_Loss: 0.0537,
# Batch number: 537, Training_Loss: 0.0030,
# Batch number: 538, Training_Loss: 0.1125,
# Batch number: 539, Training_Loss: 0.0009,
# Batch number: 540, Training_Loss: 0.0261,
# Batch number: 541, Training_Loss: 0.0152,
# Batch number: 542, Training_Loss: 0.0062,
# Batch number: 543, Training_Loss: 0.0034,
# Batch number: 544, Training_Loss: 0.0002,
# Batch number: 545, Training_Loss: 0.1444,
# Batch number: 546, Training_Loss: 0.6738,
# Batch number: 547, Training_Loss: 0.0147,
# Batch number: 548, Training_Loss: 0.0066,
# Batch number: 549, Training_Loss: 0.0274,
# Batch number: 550, Training_Loss: 0.0976,
# Batch number: 551, Training_Loss: 0.1483,
# Batch number: 552, Training_Loss: 0.0178,
# Batch number: 553, Training_Loss: 0.1350,
# Batch number: 554, Training_Loss: 0.0008,
# Batch number: 555, Training_Loss: 0.0024,
# Batch number: 556, Training_Loss: 0.0121,
# Batch number: 557, Training_Loss: 0.0025,
# Batch number: 558, Training_Loss: 0.0795,
# Batch number: 559, Training_Loss: 0.0473,
# Batch number: 560, Training_Loss: 0.2858,
# Batch number: 561, Training_Loss: 0.0979,
# Batch number: 562, Training_Loss: 0.0189,
# Batch number: 563, Training_Loss: 0.0102,
# Batch number: 564, Training_Loss: 0.0231,
# Batch number: 565, Training_Loss: 0.1741,
# Batch number: 566, Training_Loss: 0.0327,
# Batch number: 567, Training_Loss: 0.2813,
# Batch number: 568, Training_Loss: 0.0006,
# Batch number: 569, Training_Loss: 0.1146,
# Batch number: 570, Training_Loss: 0.1042,
# Batch number: 571, Training_Loss: 0.0017,
# Batch number: 572, Training_Loss: 0.0359,
# Batch number: 573, Training_Loss: 0.0280,
# Batch number: 574, Training_Loss: 0.0059,
# Batch number: 575, Training_Loss: 0.0155,
# Batch number: 576, Training_Loss: 0.0599,
# Batch number: 577, Training_Loss: 0.0062,
# Batch number: 578, Training_Loss: 0.0070,
# Batch number: 579, Training_Loss: 0.0036,
# Batch number: 580, Training_Loss: 0.0206,
# Batch number: 581, Training_Loss: 0.0277,
# Batch number: 582, Training_Loss: 0.0370,
# Batch number: 583, Training_Loss: 0.0017,
# Batch number: 584, Training_Loss: 0.1469,
# Batch number: 585, Training_Loss: 0.1999,
# Batch number: 586, Training_Loss: 0.0013,
# Batch number: 587, Training_Loss: 0.1693,
# Batch number: 588, Training_Loss: 0.1078,
# Batch number: 589, Training_Loss: 0.0052,
# Batch number: 590, Training_Loss: 0.0197,
# Batch number: 591, Training_Loss: 0.0019,
# Batch number: 592, Training_Loss: 0.0031,
# Batch number: 593, Training_Loss: 0.0407,
# Batch number: 594, Training_Loss: 0.0064,
# Batch number: 595, Training_Loss: 0.0008,
# Batch number: 596, Training_Loss: 0.0027,
# Batch number: 597, Training_Loss: 0.0138,
# Batch number: 598, Training_Loss: 0.0091,
# Batch number: 599, Training_Loss: 0.0043,
# Batch number: 600, Training_Loss: 0.0161,
# Batch number: 601, Training_Loss: 0.0013,
# Batch number: 602, Training_Loss: 0.0240,
# Batch number: 603, Training_Loss: 0.0040,
# Batch number: 604, Training_Loss: 0.1799,
# Batch number: 605, Training_Loss: 0.0439,
# Batch number: 606, Training_Loss: 0.0152,
# Batch number: 607, Training_Loss: 0.0053,
# Batch number: 608, Training_Loss: 0.0078,
# Batch number: 609, Training_Loss: 0.0415,
# Batch number: 610, Training_Loss: 0.0029,
# Batch number: 611, Training_Loss: 0.0036,
# Batch number: 612, Training_Loss: 0.0033,
# Batch number: 613, Training_Loss: 0.0003,
# Batch number: 614, Training_Loss: 0.0240,
# Batch number: 615, Training_Loss: 0.0279,
# Batch number: 616, Training_Loss: 0.0004,
# Batch number: 617, Training_Loss: 0.0021,
# Batch number: 618, Training_Loss: 0.1161,
# Batch number: 619, Training_Loss: 0.0107,
# Batch number: 620, Training_Loss: 0.0006,
# Batch number: 621, Training_Loss: 0.0150,
# Batch number: 622, Training_Loss: 0.0006,
# Batch number: 623, Training_Loss: 0.0010,
# Batch number: 624, Training_Loss: 0.0320,
# Batch number: 625, Training_Loss: 0.0238,
# Batch number: 626, Training_Loss: 0.0023,
# Batch number: 627, Training_Loss: 0.0143,
# Batch number: 628, Training_Loss: 0.1798,
# Batch number: 629, Training_Loss: 0.0054,
# Batch number: 630, Training_Loss: 0.0070,
# Batch number: 631, Training_Loss: 0.0611,
# Batch number: 632, Training_Loss: 0.0011,
# Batch number: 633, Training_Loss: 0.0025,
# Batch number: 634, Training_Loss: 0.0029,
# Batch number: 635, Training_Loss: 0.0630,
# Batch number: 636, Training_Loss: 0.0014,
# Batch number: 637, Training_Loss: 0.0417,
# Batch number: 638, Training_Loss: 0.0202,
# Batch number: 639, Training_Loss: 0.0001,
# Test Batch number: 000, Test_Loss: 0.0023, Accuracy:1.00
# Test Batch number: 001, Test_Loss: 0.0190, Accuracy:1.00
# Test Batch number: 002, Test_Loss: 0.0015, Accuracy:1.00
# Test Batch number: 003, Test_Loss: 0.0000, Accuracy:1.00
# Test Batch number: 004, Test_Loss: 0.0025, Accuracy:1.00
# Test Batch number: 005, Test_Loss: 0.0045, Accuracy:1.00
# Test Batch number: 006, Test_Loss: 0.0082, Accuracy:1.00
# Test Batch number: 007, Test_Loss: 0.0005, Accuracy:1.00
# Test Batch number: 008, Test_Loss: 0.0040, Accuracy:1.00
# Test Batch number: 009, Test_Loss: 0.4376, Accuracy:0.99
# Test Batch number: 010, Test_Loss: 0.0093, Accuracy:0.99
# Test Batch number: 011, Test_Loss: 0.0776, Accuracy:0.98
# Test Batch number: 012, Test_Loss: 0.5074, Accuracy:0.98
# Test Batch number: 013, Test_Loss: 0.0096, Accuracy:0.98
# Test Batch number: 014, Test_Loss: 0.0100, Accuracy:0.98
# Test Batch number: 015, Test_Loss: 0.0141, Accuracy:0.98
# Test Batch number: 016, Test_Loss: 0.0001, Accuracy:0.99
# Test Batch number: 017, Test_Loss: 0.0000, Accuracy:0.99

# %%
torch.save(model,'./roateNet_2.pth')

# %%
model = torch.load('roateNet_2.pth')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ploting the results

# %%
plt.figure(1,figsize=(14,14))
plt.subplot(221)
plt.xlabel('No. of Epochs')
plt.ylabel('Training loss')
plt.plot(list(range(1,31)),training_loss)
plt.scatter(training_loss.index(min(training_loss)),min(training_loss),color = 'black')
# plt.subplot(332)
# plt.xlabel('No. of Epochs')
# plt.ylabel('Testing loss')
# plt.plot(list(range(1,31)),testing_loss,color = 'green')
# plt.scatter(testing_loss.index(min(testing_loss)),min(testing_loss),color = 'black')
plt.subplot(222)
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy on test dataset')
plt.plot(list(range(1,31)),accuracy_list,color = 'orange')
plt.scatter(accuracy_list.index(max(accuracy_list)),max(accuracy_list),color = 'black')

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = torch.load('roateNet_2.pth')

# %%
model = model.cuda()

# %% [markdown]
# ### Predict Function

# %%
classes = ['0', '180', '270', '90']
def predict(model, test_image_name):
     
    transform = test_transform
 
    test_image = Image.open(test_image_name)
    plt.imshow(test_image)
     
    test_image_tensor = transform(test_image)
#     print(test_image_tensor.size())
 
    if torch.cuda.is_available():
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224).cuda()
    else:
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224)
     
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(test_image_tensor)
        _ , b = (torch.max(out,1))
#         print(b)
#         print(train_data_loader.dataset.classes[b.item()])
        ps = torch.exp(out)
        topk, topclass = ps.topk(1, dim=1)
#     print(ps)
#     print(topk,topclass)
    return classes[b.item()], topk.cpu().numpy()[0][0]

# %% [markdown]
# ### Testing

# %%
predict(model,'./Akash_54.jpg')
# Out:
# ('90', 1.0)

# %%
predict(model,'./maxresdefault.jpg')
# Out:
# ('0', 0.94622016)

# %%
predict(model,'./Atharva_60.jpeg')
# Out:
# ('270', 0.99999905)

# %%
predict(model,'./Hiral_69.jpg_90.jpg')
# Out:
# ('90', 1.0)

# %%
predict(model,'./image7 (2).jpeg_180.jpg')
# Out:
# ('180', 1.0)

# %% [markdown]
# #### Class Activation Mapping

# %%
from PIL import Image
from gradcam.utils import visualize_cam, Normalize
from gradcam import GradCAM, GradCAMpp

# %%
pil_img = Image.open("./Krutika_15.jpg_270.jpg")
normed_torch_img = test_transform(pil_img).unsqueeze(0).cuda()
resnet = model
resnet.eval()
resnet.cuda()
gradcam = GradCAMpp.from_config(model_type='resnet',
                              arch=resnet, layer_name='layer4')
mask, logit = gradcam(normed_torch_img, class_idx=1)
heatmap, cam_result = visualize_cam(mask, normed_torch_img)
a = transforms.ToPILImage()

heatmap, cam_result = visualize_cam(mask, normed_torch_img)

a = transforms.ToPILImage()

img1 = a(heatmap)
img2 = a(cam_result)
plt.figure(1,figsize=(14,14))
plt.subplot(331)
plt.xlabel('Original')
plt.imshow(pil_img)
plt.subplot(332)
plt.xlabel('Heatmap')
plt.imshow(img1,cmap='jet', alpha = 0.5)
plt.subplot(333)
plt.xlabel('GradCAM')
plt.imshow(img2,cmap='jet')

# print(predict(model,"./Madhav_15.jpg_270.jpg"))

# %%
pil_img = Image.open("./image7 (2).jpeg_180.jpg")
normed_torch_img = test_transform(pil_img).unsqueeze(0).cuda()
resnet = model
resnet.eval()
resnet.cuda()
gradcam = GradCAMpp.from_config(model_type='resnet',
                              arch=resnet, layer_name='layer4')
mask, logit = gradcam(normed_torch_img, class_idx=1)
heatmap, cam_result = visualize_cam(mask, normed_torch_img)
a = transforms.ToPILImage()

heatmap, cam_result = visualize_cam(mask, normed_torch_img)

a = transforms.ToPILImage()

img1 = a(heatmap)
img2 = a(cam_result)
plt.figure(1,figsize=(14,14))
plt.subplot(331)
plt.xlabel('Original')
plt.imshow(pil_img)
plt.subplot(332)
plt.xlabel('Heatmap')
plt.imshow(img1,cmap='jet', alpha = 0.5)
plt.subplot(333)
plt.xlabel('GradCAM')
plt.imshow(img2,cmap='jet')

# print(predict(model,"./image7 (2).jpeg_180.jpg"))

# %%
pil_img = Image.open("./Abhay_90.jpg_90.jpg")
normed_torch_img = test_transform(pil_img).unsqueeze(0).cuda()
resnet = model
resnet.eval()
resnet.cuda()
gradcam = GradCAMpp.from_config(model_type='resnet',
                              arch=resnet, layer_name='layer4')
mask, logit = gradcam(normed_torch_img, class_idx=1)
heatmap, cam_result = visualize_cam(mask, normed_torch_img)
a = transforms.ToPILImage()

heatmap, cam_result = visualize_cam(mask, normed_torch_img)

a = transforms.ToPILImage()

img1 = a(heatmap)
img2 = a(cam_result)
plt.figure(1,figsize=(14,14))
plt.subplot(331)
plt.xlabel('Original')
plt.imshow(pil_img)
plt.subplot(332)
plt.xlabel('Heatmap')
plt.imshow(img1,cmap='jet', alpha = 0.5)
plt.subplot(333)
plt.xlabel('GradCAM')
plt.imshow(img2,cmap='jet')

# print(predict(model,"./image7 (2).jpeg_180.jpg"))
# Out:
# C:\Users\Akansh Maurya\anaconda3\lib\site-packages\torch\nn\functional.py:2796: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
import cv2

# %% [markdown]
# ### Correcting Orientation

# %%
from PIL import Image
from scipy import ndimage
def correct_orientation(model,image):
    classes = ['0', '180', '270', '90']
    model = torch.load(model)
    img = Image.open(image)
    plt.figure(1,figsize=(8,8))
    plt.subplot(221)
    plt.xlabel('Original image')
    plt.imshow(img)
    img_tensor = test_transform(img)
    if torch.cuda.is_available():
        img_tensor = img_tensor.view(1, 3, 224, 224).cuda()
    else:
        img_tensor = img_tensor.view(1, 3, 224, 224)
        
    with torch.no_grad():
        model.eval()
        out = model(img_tensor)
        _ , b = (torch.max(out,1))
        angle = int(classes[b.item()])
        rot_angle = 360-angle
        rotated = ndimage.rotate(img, rot_angle,mode = 'nearest')
        plt.subplot(222)
        plt.xlabel('Corrected image')
        plt.imshow(rotated)
        cv2.imwrite('./correct_orientation'+image,cv2.cvtColor(rotated, cv2.COLOR_RGB2BGR))

# %%
correct_orientation('roateNet_2.pth','./Atharva_60.jpeg')

# %%
correct_orientation('roateNet_2.pth','./Akash_54.jpg')

# %%
plt.figure(2,(12,12))
# plt.subplot(331)
correct_orientation("roateNet_2.pth",'./Krutika_15.jpg_270.jpg')
# # # plt.subplot(332
# correct_orientation("roateNet_2.pth",'./Krutika_15.jpg_270.jpg'))

# %%
correct_orientation('roateNet_2.pth','./Srinath_89.jpeg')

# %%
correct_orientation('roateNet_2.pth','./Subramanian_4.jpg')
